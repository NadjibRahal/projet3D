# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.getcwd()
os.chdir("/content/drive/MyDrive/TP_Master_PAR/Materials/code")

# %%
import sys

# Ajouter le répertoire
sys.path.append("/content/drive/MyDrive/TP_Master_PAR/Materials/code")

# %%
import pointnet

# %%
# !python pointnet.py
# Out:
# Classes:  {0: 'bathtub', 1: 'bed', 2: 'chair', 3: 'desk', 4: 'dresser', 5: 'monitor', 6: 'night_stand', 7: 'sofa', 8: 'table', 9: 'toilet'}
# Train dataset size:  2463
# Test dataset size:  572
# Number of classes:  10
# Sample pointcloud shape:  torch.Size([1024, 3])
# Number of parameters in the Neural Networks:  1573376
# Device:  cpu
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/TP_Master_PAR/Materials/code/pointnet.py", line 219, in <module>
#     train(model, device, train_loader, test_loader, epochs=250)
#   File "/content/drive/MyDrive/TP_Master_PAR/Materials/code/pointnet.py", line 165, in train
#     for i, data in enumerate(train_loader, 0):
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py", line 732, in __next__
#     data = self._next_data()
#            ^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py", line 788, in _next_data
#     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/data/_utils/fetch.py", line 52, in fetch
#     data = [self.dataset[idx] for idx in possibly_batched_index]
#             ~~~~~~~~~~~~^^^^^
#   File "/content/drive/MyDrive/TP_Master_PAR/Materials/code/pointnet.py", line 84, in __getitem__
#     data = ply.read_ply(ply_path)
#            ^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/drive/MyDrive/TP_Master_PAR/Materials/code/ply.py", line 121, in read_ply
#     if b'ply' not in plyfile.readline():
#                      ^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
